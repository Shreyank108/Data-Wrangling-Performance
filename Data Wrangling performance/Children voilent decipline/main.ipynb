# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("childrens_violence new.csv")

# %%
data.head()
# Out:
#           Entity Code  Year  Childrens Violent Discipline Rate\n\n\n\n\n\n
# 0        Georgia  GEO  2005                                             67
# 1     Tajikistan  TJK  2005                                             78
# 2     Azerbaijan  AZE  2006                                             77
# 3   Burkina Faso  BFA  2006                                             83
# 4  Cote d'Ivoire  CIV  2006                                             91

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 4 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Entity                                   73 non-null     object
#  1   Code                                     73 non-null     object
#  2   Year                                     73 non-null     int64
#  3   Childrens Violent Discipline Rate
#
#
#
#
#
#   73 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 2.4+ KB

# %%
data.describe()
# Out:
#               Year  Childrens Violent Discipline Rate\n\n\n\n\n\n
# count    73.000000                                      73.000000
# mean   2011.328767                                      74.931507
# std       2.708294                                      14.041930
# min    2005.000000                                      36.000000
# 25%    2010.000000                                      68.000000
# 50%    2012.000000                                      78.000000
# 75%    2014.000000                                      85.000000
# max    2015.000000                                      94.000000

# %%
data.shape
# Out:
# (73, 4)

# %%
data.isnull().sum()
# Out:
# Entity                                           0
# Code                                             0
# Year                                             0
# Childrens Violent Discipline Rate\n\n\n\n\n\n    0
# dtype: int64

# %%
data.dtypes
# Out:
# Entity                                           object
# Code                                             object
# Year                                              int64
# Childrens Violent Discipline Rate\n\n\n\n\n\n     int64
# dtype: object

# %%
data.hist(bins=20, figsize=(12, 10))
plt.suptitle('baccho ka zazba')
plt.show()

# %%
data.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Childrens Violent Discipline Rate\n\n\n\n\n\n'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()

# Visualization
plt.figure(figsize=(15, 8))
sns.scatterplot(x='Year', y='Childrens Violent Discipline Rate', hue='Entity', data=data, palette='viridis')
plt.title('Childrens Violent Discipline Rate Over Time')
plt.xlabel('Year')
plt.ylabel('Childrens Violent Discipline Rate')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
